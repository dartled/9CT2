# %%
#!/usr/bin/env pybricks-micropython

from pybricks.hubs import EV3Brick
from pybricks.ev3devices import Motor
from pybricks.parameters import Port
from pybricks.robotics import DriveBase

# Initialize the EV3 Brick.
ev3 = EV3Brick()

# Initialize the motors.
left_motor = Motor(Port.B)
right_motor = Motor(Port.C)

# Initialize the drive base.
robot = DriveBase(left_motor, right_motor, wheel_diameter=55.5, axle_track=104)

robot.straight(600)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(650)
ev3.speaker.beep()

robot.turn(114)
ev3.speaker.beep()

robot.straight(600)
ev3.speaker.beep()

robot.turn(70)
ev3.speaker.beep()

robot.straight(645)

# %% [markdown]
# 1. First Version of code. Obtained the red block, then ran off the board. Realised that exact angles does not matter as the robot does not match them exactly. Messed up last angle, was meant to turn 70 degrees left which would be -70 degrees

# %%
#!/usr/bin/env pybricks-micropython

from pybricks.hubs import EV3Brick
from pybricks.ev3devices import Motor
from pybricks.parameters import Port
from pybricks.robotics import DriveBase

# Initialize the EV3 Brick.
ev3 = EV3Brick()

# Initialize the motors.
left_motor = Motor(Port.B)
right_motor = Motor(Port.C)

# Initialize the drive base.
robot = DriveBase(left_motor, right_motor, wheel_diameter=55.5, axle_track=104)

robot.straight(600)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(650)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(600)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(645)

# %% [markdown]
# 2. Changed turns to 90 degrees. First test worked, however not consistent. Obtained red block, then turned and slightly missed yellow block, however on the next turn it managed to obtain yellow block and managed to push both into zone. However, the outcome was inconsistent.

# %%
#!/usr/bin/env pybricks-micropython

from pybricks.hubs import EV3Brick
from pybricks.ev3devices import Motor
from pybricks.parameters import Port
from pybricks.robotics import DriveBase

# Initialize the EV3 Brick.
ev3 = EV3Brick()

# Initialize the motors.
left_motor = Motor(Port.B)
right_motor = Motor(Port.C)

# Initialize the drive base.
robot = DriveBase(left_motor, right_motor, wheel_diameter=55.5, axle_track=104)

robot.straight(575)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(630)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(575)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(645)

# %% [markdown]
# 3. Changed the width values from 600 to 575, to prevent robot from getting stuck on edge of board. After obtaining red block, robot would turn but was short and doesn't manage to grab yellow block within claw as well as going too far forward, falling off board.

# %%
#!/usr/bin/env pybricks-micropython

from pybricks.hubs import EV3Brick
from pybricks.ev3devices import Motor
from pybricks.parameters import Port
from pybricks.robotics import DriveBase

# Initialize the EV3 Brick.
ev3 = EV3Brick()

# Initialize the motors.
left_motor = Motor(Port.B)
right_motor = Motor(Port.C)

# Initialize the drive base.
robot = DriveBase(left_motor, right_motor, wheel_diameter=55.5, axle_track=104)

robot.straight(575)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(640)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(550)
ev3.speaker.beep()

robot.turn(90)
ev3.speaker.beep()

robot.straight(645)

# %% [markdown]
# 4. Final code before shown to teacher. Altered varaiable after first turn from 630 to 640 to prevent robot from missing yellow block. Altered value after second turn from 575 to 550 to prevent robot from going off the edge. Managed to catch red block and yellow block, however after obtaining yellow block, it went too far forward which resulted in the yellow block falling off. After the robot pushed off the yellow block, made a turn that was not 90 degrees (possibly because of the duct tape) and was slightly off to the right which resulted in robot falling off board with red block.
